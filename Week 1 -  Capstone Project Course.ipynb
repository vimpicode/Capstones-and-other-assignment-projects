# %% [markdown]
# # Week 1: Capstone Project

# %% [markdown]
# Create a new repository on your Github account and name it Coursera_Capstone. I have prepared a guide to walk you through the process of creating a repository and setting it up. For Mac users, click here. For Windows users, click here.
#
# Now, start a Jupyter Notebook using any platform that you are comfortable with and do the following:

# %% [markdown]
# ## Task 1- Write some markdown to explain that this notebook will be mainly used for the capstone project.

# %% [markdown]
# #### This notebook is for the first week module of  "Applied Data Science Capstone" course. Some of  the main activities in this notebook will be (a) Import the pandas library as pd, (b) Import the Numpy library as np and (c) Print the statement "Hello Capstone Project Course!".

# %% [markdown]
# ## Task 2- Import the pandas library as pd.

# %%
# Let's import pandas library as pd
import pandas as pd

# %% [markdown]
# ## Task 3 - Import the Numpy library as np.

# %%
# Let's import Numpy library as np
import numpy as np

# %% [markdown]
# ## Task 4- Print the following the statement: Hello Capstone Project Course!

# %%
print ("Hello Campstone Course!")
# Out:
# Hello Campstone Course!
